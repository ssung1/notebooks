# %%
"""
import sys
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install pandas
"""
# Out:
# '\nimport sys\n!{sys.executable} -m pip install matplotlib\n!{sys.executable} -m pip install pandas\n'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.arange(-10, 10, .1)

# %%
fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(1, 1, 1, xticks=np.arange(-25, 25, 5), yticks=np.arange(-25, 25, 5), aspect='equal')
ax.set_xlim([-25, 25])
ax.set_ylim([-25, 25])
ax.grid(True)

# ax.plot([[2, 15], [3, 14], [6, 14], [9, 12]])
ax.plot([ 2,  3,  6,  9,  7,  8,  4,  3,  1, -2, -3, -7, -5, -10, -7, -6, -4, -2, -1],
        [15, 14, 14, 12, 12, 10, 12, 10, 12,  9, 12, 10, 13,  12, 14, 14, 15, 15, 16])

ax.plot([-1, -3,  0,  2,  3,  2,  1,  0, -1, -1, -2, -1],
        [16, 22, 23, 15, 13, 14, 13, 14, 13, 14, 14, 16])

ax.plot([-4, -7, -4, -4],
        [ 1,  1,  6,  1])

ax.plot([5, 7, 4, 5],
        [1, 3, 6, 1])

ax.plot([-2, 0,  2, -2],
        [-4, 1, -4, -4])

ax.plot([ 2,   4,  6,  8, 11,   9,   6,   3,   0,  -4,  -6,  -9, -10, -7, -6,  -5, -3,   0,  2],
        [-7, -11, -7, -9, -7, -11, -17, -14, -19, -14, -16, -10,  -5, -9, -8, -11, -8, -11, -7])

ax.plot([ 9, 12, 14, 15, 15,  13,  11,   9,   5,   0,  -4,  -7,  -9, -12, -14, -15, -16, -15, -14, -12, -10],
        [12,  8,  3, -2, -8, -14, -17, -20, -22, -23, -22, -21, -20, -18, -15, -12, -6,    1,   5,   9,  12])
